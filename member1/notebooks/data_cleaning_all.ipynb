# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql

# 数据库连接配置
# 替换为您的实际数据库连接信息
db_connection_str = 'mysql+pymysql://root:123456@127.0.0.1:3306/DIDatax'
db_connection = create_engine(db_connection_str)

# 待检查的表列表
tables = [
    'ga_session',
    'ga_custom_dimension',
    'ga_hit',
    'ga_total',
    'ga_geo_network',
    'ga_traffic_source',
    'ga_device'
]

print("数据库连接成功。准备检查以下表：", tables)
# Out:
# 数据库连接成功。准备检查以下表： ['ga_session', 'ga_custom_dimension', 'ga_hit', 'ga_total', 'ga_geo_network', 'ga_traffic_source', 'ga_device']

# %%
from IPython.display import display

def check_data_quality(table_name, engine):
    print(f"\n{'='*20} {table_name} {'='*20}")
    try:
        # 读取数据 (如果数据量非常大，建议添加 limit 或分块读取，这里假设数据量在内存可承受范围内)
        query = f"SELECT * FROM {table_name}"
        df = pd.read_sql(query, engine)
        
        # 1. 基本信息
        print(f"数据量 (Rows, Columns): {df.shape}")
        
        # 2. 重复值检查
        duplicates = df.duplicated().sum()
        print(f"完全重复行数: {duplicates}")
        
        # 3. 缺失值检查 (只显示有缺失值的列)
        missing = df.isnull().sum()
        missing_cols = missing[missing > 0]
        if not missing_cols.empty:
            print("\n缺失值统计 (列名: 缺失数):")
            print(missing_cols)
        else:
            print("\n无缺失值。")
            
        # 4. 数据预览
        print("\n前 5 行预览:")
        return df.head()
    except Exception as e:
        print(f"读取或处理表 {table_name} 时发生错误: {e}")
        return None

# 循环执行检查
for table in tables:
    display_df = check_data_quality(table, db_connection)
    if display_df is not None:
        display(display_df)
# Out:
# ==================== ga_session ====================
# 数据量 (Rows, Columns): (71812, 9)
# 完全重复行数: 0
#
# 缺失值统计 (列名: 缺失数):
# user_id    71812
# dtype: int64
#
# 前 5 行预览:
#                                      uid      full_visitor_id user_id  \
# 0  0005012088711421541150073609420170722  0005012088711421541    None
# 1  0010796018926816522150073453920170722  0010796018926816522    None
# 2  0017221597005564730150070919820170722  0017221597005564730    None
# 3  0021476320702567884150075792820170722  0021476320702567884    None
# 4  0021908729511710870150075228120170722  0021908729511710870    None
#
#    visit_number    visit_id  visit_start_time      date  \
# 0             2  1500736094        1500736094  20170722
# 1             1  1500734539        1500734539  20170722
# 2             2  1500709198        1500709198  20170722
# 3             1  1500757928        1500757928  20170722
# 4             1  1500752281        1500752281  20170722
#
#   social_engagement_type channel_grouping
# 0   Not Socially Engaged   Organic Search
# 1   Not Socially Engaged   Organic Search
# 2   Not Socially Engaged   Organic Search
# 3   Not Socially Engaged   Organic Search
# 4   Not Socially Engaged           Direct
# ==================== ga_custom_dimension ====================
# 数据量 (Rows, Columns): (60585, 4)
# 完全重复行数: 0
#
# 缺失值统计 (列名: 缺失数):
# visit_id    60585
# dtype: int64
#
# 前 5 行预览:
#                                      uid visit_id  dim_index          value
# 0  0005012088711421541150073609420170722     None          4           APAC
# 1  0010796018926816522150073453920170722     None          4  North America
# 2  0017221597005564730150070919820170722     None          4           EMEA
# 3  0021476320702567884150075792820170722     None          4  North America
# 4  0024932550342595467150074438920170722     None          4  North America
# ==================== ga_hit ====================
# 数据量 (Rows, Columns): (324096, 32)
# 完全重复行数: 0
#
# 缺失值统计 (列名: 缺失数):
# source_property_info     324096
# is_entrance              252300
# is_exit                  252300
# latency_tracking         321831
# publisher                324096
# transaction              168592
# referer                  243958
# refund                   324096
# promotion_action_info    278478
# item                     168592
# content_info             324096
# event_info               272819
# dtype: int64
#
# 前 5 行预览:
#                                      uid data_source source_property_info  \
# 0  0005012088711421541150073609420170722         web                 None
# 1  0010796018926816522150073453920170722         web                 None
# 2  0010796018926816522150073453920170722         web                 None
# 3  0010796018926816522150073453920170722         web                 None
# 4  0010796018926816522150073453920170722         web                 None
#
#                                  e_commerce_action  \
# 0  {"action_type": "0", "step": 1, "option": null}
# 1  {"action_type": "0", "step": 1, "option": null}
# 2  {"action_type": "0", "step": 1, "option": null}
# 3  {"action_type": "1", "step": 1, "option": null}
# 4  {"action_type": "2", "step": 1, "option": null}
#
#                                       exception_info experiment  hitNumber  \
# 0  {"description": null, "isFatal": true, "except...         []          1
# 1  {"description": null, "isFatal": true, "except...         []          1
# 2  {"description": null, "isFatal": true, "except...         []          2
# 3  {"description": null, "isFatal": true, "except...         []          3
# 4  {"description": null, "isFatal": true, "except...         []          4
#
#    hour  is_entrance  is_exit  ...  \
# 0     8          1.0      1.0  ...
# 1     7          1.0      NaN  ...
# 2     7          NaN      NaN  ...
# 3     7          NaN      NaN  ...
# 4     7          NaN      NaN  ...
#
#                                            promotion  \
# 0                                                 []
# 1  [{"promoId": "Apparel Row 1", "promoName": "Ap...
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                          promotion_action_info  \
# 0                                         None
# 1  {"promoIsView": true, "promoIsClick": null}
# 2                                         None
# 3                                         None
# 4                                         None
#
#                                                 item  \
# 0                                               None
# 1                                               None
# 2  {"transactionId": null, "productName": null, "...
# 3                                               None
# 4                                               None
#
#                                        content_group content_info  \
# 0  {"contentGroup1": "(not set)", "contentGroup2"...         None
# 1  {"contentGroup1": "(not set)", "contentGroup2"...         None
# 2  {"contentGroup1": "(not set)", "contentGroup2"...         None
# 3  {"contentGroup1": "(not set)", "contentGroup2"...         None
# 4  {"contentGroup1": "(not set)", "contentGroup2"...         None
#
#                                             app_info  \
# 0  {"name": null, "version": null, "id": null, "i...
# 1  {"name": null, "version": null, "id": null, "i...
# 2  {"name": null, "version": null, "id": null, "i...
# 3  {"name": null, "version": null, "id": null, "i...
# 4  {"name": null, "version": null, "id": null, "i...
#
#                                           event_info custom_variables  \
# 0                                               None               []
# 1                                               None               []
# 2                                               None               []
# 3  {"eventCategory": "Enhanced Ecommerce", "event...               []
# 4                                               None               []
#
#   custom_dimensions custom_metrics
# 0                []             []
# 1                []             []
# 2                []             []
# 3                []             []
# 4                []             []
#
# [5 rows x 32 columns]
# ==================== ga_total ====================
# 数据量 (Rows, Columns): (71812, 13)
# 完全重复行数: 0
#
# 缺失值统计 (列名: 缺失数):
# bounces                      35404
# new_visits                   17131
# pageviews                       16
# screenviews                  71812
# session_quality_dim           5989
# time_on_screen               71812
# time_on_site                 36528
# total_transaction_revenue    70781
# transactions                 70781
# unique_screen_views          71812
# dtype: int64
#
# 前 5 行预览:
#                                      uid  bounces  hits  new_visits  \
# 0  0005012088711421541150073609420170722      1.0     1         NaN
# 1  0010796018926816522150073453920170722      NaN     6         1.0
# 2  0017221597005564730150070919820170722      1.0     1         NaN
# 3  0021476320702567884150075792820170722      1.0     1         1.0
# 4  0021908729511710870150075228120170722      NaN    12         1.0
#
#    pageviews screenviews  session_quality_dim time_on_screen  time_on_site  \
# 0        1.0        None                  1.0           None           NaN
# 1        5.0        None                  1.0           None          64.0
# 2        1.0        None                  1.0           None           NaN
# 3        1.0        None                  1.0           None           NaN
# 4       11.0        None                  4.0           None         547.0
#
#    total_transaction_revenue  transactions unique_screen_views  visits
# 0                        NaN           NaN                None       1
# 1                        NaN           NaN                None       1
# 2                        NaN           NaN                None       1
# 3                        NaN           NaN                None       1
# 4                        NaN           NaN                None       1
# ==================== ga_geo_network ====================
# 数据量 (Rows, Columns): (71812, 12)
# 完全重复行数: 0
#
# 无缺失值。
#
# 前 5 行预览:
#                                      uid continent     sub_continent  \
# 0  0005012088711421541150073609420170722      Asia    Southeast Asia
# 1  0010796018926816522150073453920170722  Americas  Northern America
# 2  0017221597005564730150070919820170722    Europe    Eastern Europe
# 3  0021476320702567884150075792820170722  Americas  Northern America
# 4  0021908729511710870150075228120170722  Americas     South America
#
#          country                         region  \
# 0      Singapore                      (not set)
# 1  United States  not available in demo dataset
# 2         Russia  not available in demo dataset
# 3  United States  not available in demo dataset
# 4           Peru                    Lima Region
#
#                            metro                           city  \
# 0                      (not set)                      Singapore
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4                      (not set)                    La Victoria
#
#                          city_id                       latitude  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                        longitude   network_domain  \
# 0  not available in demo dataset        m1.com.sg
# 1  not available in demo dataset        (not set)
# 2  not available in demo dataset            rt.ru
# 3  not available in demo dataset        (not set)
# 4  not available in demo dataset  unknown.unknown
#
#                 network_location
# 0  not available in demo dataset
# 1  not available in demo dataset
# 2  not available in demo dataset
# 3  not available in demo dataset
# 4  not available in demo dataset
# ==================== ga_traffic_source ====================
# 数据量 (Rows, Columns): (71812, 10)
# 完全重复行数: 0
#
# 缺失值统计 (列名: 缺失数):
# ad_content        71141
# campaign_code     71812
# is_true_direct    47988
# keyword           33682
# referral_path     54545
# dtype: int64
#
# 前 5 行预览:
#                                      uid ad_content  \
# 0  0005012088711421541150073609420170722       None
# 1  0010796018926816522150073453920170722       None
# 2  0017221597005564730150070919820170722       None
# 3  0021476320702567884150075792820170722       None
# 4  0021908729511710870150075228120170722       None
#
#                                   adwords_click_info   campaign campaign_code  \
# 0  {"campaignId": null, "adGroupId": null, "creat...  (not set)          None
# 1  {"campaignId": null, "adGroupId": null, "creat...  (not set)          None
# 2  {"campaignId": null, "adGroupId": null, "creat...  (not set)          None
# 3  {"campaignId": null, "adGroupId": null, "creat...  (not set)          None
# 4  {"campaignId": null, "adGroupId": null, "creat...  (not set)          None
#
#    is_true_direct         keyword   medium referral_path    source
# 0             1.0  (not provided)  organic          None    google
# 1             NaN  (not provided)  organic          None    google
# 2             1.0  (not provided)  organic          None    google
# 3             NaN  (not provided)  organic          None    google
# 4             1.0            None   (none)          None  (direct)
# ==================== ga_device ====================
# 数据量 (Rows, Columns): (71812, 17)
# 完全重复行数: 0
#
# 缺失值统计 (列名: 缺失数):
# java_enabled    71812
# dtype: int64
#
# 前 5 行预览:
#                                      uid browser  \
# 0  0005012088711421541150073609420170722  Safari
# 1  0010796018926816522150073453920170722  Chrome
# 2  0017221597005564730150070919820170722  Chrome
# 3  0021476320702567884150075792820170722  Safari
# 4  0021908729511710870150075228120170722  Chrome
#
#                     browser_size                browser_version  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#   device_category             mobile_device_info  \
# 0          mobile  not available in demo dataset
# 1         desktop  not available in demo dataset
# 2         desktop  not available in demo dataset
# 3          mobile  not available in demo dataset
# 4         desktop  not available in demo dataset
#
#     mobile_device_marketing_name            mobile_device_model  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#            mobile_input_selector operating_system  \
# 0  not available in demo dataset              iOS
# 1  not available in demo dataset          Windows
# 2  not available in demo dataset          Windows
# 3  not available in demo dataset              iOS
# 4  not available in demo dataset          Windows
#
#         operating_system_version         mobile_device_branding  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                    flash_version java_enabled                       language  \
# 0  not available in demo dataset         None  not available in demo dataset
# 1  not available in demo dataset         None  not available in demo dataset
# 2  not available in demo dataset         None  not available in demo dataset
# 3  not available in demo dataset         None  not available in demo dataset
# 4  not available in demo dataset         None  not available in demo dataset
#
#                    screen_colors              screen_resolution
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset

# %%
import os

# 创建保存目录 (相对路径，相对于 notebooks 文件夹)
# 也就是 e:\Grade3\2-DataIntegration\Assignments-DI\As2\data\cleaned
output_dir = os.path.abspath(os.path.join(os.getcwd(), '..', 'data', 'cleaned'))

if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    print(f"已创建目录: {output_dir}")
else:
    print(f"输出目录已存在: {output_dir}")

def clean_and_save(table_name, engine):
    print(f"正在处理表: {table_name}...")
    try:
        query = f"SELECT * FROM {table_name}"
        df = pd.read_sql(query, engine)
        
        original_count = len(df)
        
        # 1. 初步清洗：去重
        df.drop_duplicates(inplace=True)
        dedup_count = len(df)
        
        if original_count != dedup_count:
            print(f"  - 发现并删除了 {original_count - dedup_count} 行重复数据")
        else:
            print("  - 无完全重复行")

        # 2. 导出为 CSV (提供给其他组员分析使用)
        # 使用 utf-8-sig 编码以防止 Excel 打开中文乱码
        file_path = os.path.join(output_dir, f"{table_name}.csv")
        df.to_csv(file_path, index=False, encoding='utf-8-sig')
        print(f"  - 已导出至: {file_path}")
        
    except Exception as e:
        print(f"  - 处理失败: {e}")

print("-" * 30)
print("开始执行清洗与导出任务（供 Team Member 2-5 使用）...")

# 循环执行清洗并保存
for table in tables:
    clean_and_save(table, db_connection)

print("\n所有清洗后的数据文件生成完毕！")
# Out:
# 输出目录已存在: E:\Grade3\2-DataIntegration\Assignments-DI\As2\data\cleaned
# ------------------------------
# 开始执行清洗与导出任务（供 Team Member 2-5 使用）...
# 正在处理表: ga_session...
#   - 无完全重复行
#   - 已导出至: E:\Grade3\2-DataIntegration\Assignments-DI\As2\data\cleaned\ga_session.csv
# 正在处理表: ga_custom_dimension...
#   - 无完全重复行
#   - 已导出至: E:\Grade3\2-DataIntegration\Assignments-DI\As2\data\cleaned\ga_custom_dimension.csv
# 正在处理表: ga_hit...
#   - 无完全重复行
#   - 已导出至: E:\Grade3\2-DataIntegration\Assignments-DI\As2\data\cleaned\ga_hit.csv
# 正在处理表: ga_total...
#   - 无完全重复行
#   - 已导出至: E:\Grade3\2-DataIntegration\Assignments-DI\As2\data\cleaned\ga_total.csv
# 正在处理表: ga_geo_network...
#   - 无完全重复行
#   - 已导出至: E:\Grade3\2-DataIntegration\Assignments-DI\As2\data\cleaned\ga_geo_network.csv
# 正在处理表: ga_traffic_source...
#   - 无完全重复行
#   - 已导出至: E:\Grade3\2-DataIntegration\Assignments-DI\As2\data\cleaned\ga_traffic_source.csv
# 正在处理表: ga_device...
#   - 无完全重复行
#   - 已导出至: E:\Grade3\2-DataIntegration\Assignments-DI\As2\data\cleaned\ga_device.csv
#
# 所有清洗后的数据文件生成完毕！
